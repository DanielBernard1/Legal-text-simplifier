# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
with open("../data/CUADv1.json") as f:
    data = json.load(f)

test = pd.DataFrame.from_records(data)

test.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     510 non-null    object
#  1   version  510 non-null    str
# dtypes: object(1), str(1)
# memory usage: 8.1+ KB

# %%
test.describe()
# Out:
#                                                      data   version
# count                                                 510       510
# unique                                                510         1
# top     {'title': 'LIMEENERGYCO_09_09_1999-EX-10-DISTR...  aok_v1.0
# freq                                                    1       510

# %%
with open("../data/all_v1.json") as f:
    tos_data = json.load(f)

tos_df = pd.DataFrame(tos_data.values())
tos_df.head()
# Out:
#                            doc                        id  \
# 0  Pokemon GO Terms of Service  5786730a6cca83a54c0035b7
# 1  Pokemon GO Terms of Service  57866df76cca83a54c0035a1
# 2  Pokemon GO Terms of Service  5786730a6cca83a54c0035b6
# 3  Pokemon GO Terms of Service  57866df76cca83a54c0035a0
# 4  Pokemon GO Terms of Service  57866df76cca83a54c00359f
#
#                                        original_text  \
# 0  welcome to the pokémon go video game services ...
# 1  by using our services you are agreeing to thes...
# 2  if you want to use certain features of the ser...
# 3  during game play please be aware of your surro...
# 4  subject to your compliance with these terms ni...
#
#                                    reference_summary  \
# 0                                                hi.
# 1  by playing this game you agree to these terms....
# 2  you have to use google pokemon trainer club or...
# 3  don t die or hurt others and if you do it s no...
# ...

# %%
tos_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 446 entries, 0 to 445
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   doc                446 non-null    str
#  1   id                 85 non-null     str
#  2   original_text      446 non-null    str
#  3   reference_summary  446 non-null    str
#  4   title              85 non-null     str
#  5   uid                446 non-null    str
#  6   case_code          117 non-null    str
#  7   case_text          117 non-null    str
#  8   note               361 non-null    str
#  9   title_code         352 non-null    str
#  10  title_text         352 non-null    str
#  11  urls               361 non-null    str
#  12  tldr_code          101 non-null    str
#  13  tldr_text          101 non-null    str
# dtypes: str(14)
# memory usage: 48.9 KB

# %%
tos_df = tos_df[["doc", "original_text", "reference_summary"]]
tos_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 446 entries, 0 to 445
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   doc                446 non-null    str
#  1   original_text      446 non-null    str
#  2   reference_summary  446 non-null    str
# dtypes: str(3)
# memory usage: 10.6 KB

# %%
tos_df["summary_word_count"] = tos_df["reference_summary"].str.split().str.len()
tos_df.sort_values("summary_word_count").head(15)
# Out:
#                                             doc  \
# 0                   Pokemon GO Terms of Service
# 52    Android SDK License Agreement (June 2014)
# 358                              Privacy Policy
# 393                           Privacy Statement
# 60    Android SDK License Agreement (June 2014)
# 144                            Terms of Service
# 419                               Cookie Policy
# 18                  Pokemon GO Terms of Service
# 68   Google Play Game Services (May 15th, 2013)
# 45                     YouTube Terms of Service
# 96                               Privacy Policy
# 59    Android SDK License Agreement (June 2014)
# 323                                Terms of Use
# 111                 Terms and Conditions of Use
# 47    Android SDK License Agreement (June 2014)
#
#                                          original_text  \
# 0    welcome to the pokémon go video game services ...
# 52   you agree that you will not engage in any acti...
# ...

# %%
import os
tos_df.to_csv("../data/tos_for_review.csv", index=False)
os.getcwd()
# Out:
# '/home/daniel/Legal-text-simplifier/notebooks'

# %%
df2 = pd.read_csv("../data/tos_for_review.csv")
df2.head()
len(df2)
# Out:
# 444
